# %% [markdown]
# This is a markdown cell
#
# $$this\_is\_a\_latex\_equation = \frac{equa}{tion}$$
#
# ## HTML table
# <center>
# <table>
#     <tr>
#         <td>a</td>
#         <td>b</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>2</td>
#     </tr>
# </center>
#
# ## An image
#
# <img src="data:image/png;base64,..." />

# %% [markdown]
# Hola

# %%
a = 3
a
# Out:
# 3

# %%
a = 3
print(a)
# Out:
# 3

# %%
from IPython.display import HTML
HTML("<H1>Hola</H1>")
# Out:
# <H1>Hola</H1>

# %%
# %%HTML
# \begin{equation*}
#   1 + 2 = 3
# \end{equation*}
# Out:
# \begin{equation*}
#   1 + 2 = 3
# \end{equation*}

# %%
a = 3
